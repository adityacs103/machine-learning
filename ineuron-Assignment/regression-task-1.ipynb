# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/Nehal-Dipti/DATA_SET/main/Algerian_forest_fires_dataset_UPDATE%20(1).csv')

# %%
data.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI    Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3    0  not fire
# 4  0.5  not fire

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
data.drop(columns='Classes  ',axis=1,inplace=True)

# %%
data.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC              object
# ISI            float64
# BUI            float64
# FWI             object
# dtype: object

# %%
data.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# dtype: int64

# %%
data['DC']=data['DC'].astype(float)

# %%
data=data.replace(r'14.6 9',14.69,regex=True)

# %%
data.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
#  RH              int64
#  Ws              int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI             object
# dtype: object

# %%
data[data['FWI']=='fire   '].count()
# Out:
# day            1
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# dtype: int64

# %%
data['FWI']=data['FWI'].replace(r'fire   ',None,regex=True)

# %%
data['FWI']=data['FWI'].astype(float)

# %%
data.drop(columns=['year'],inplace=True)

# %%
data.head()
# Out:
#    day  month  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0    1      6           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9  0.5

# %%
x=data.drop(columns=['Temperature'])

# %%
x.head()
# Out:
#    day  month   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0    1      6   57   18    0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6   61   13    1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6   82   22   13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6   89   13    2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6   77   16    0.0  64.8  3.0  14.2  1.2  3.9  0.5

# %%
data.isnull().sum()
# Out:
# day            0
# month          0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            1
# dtype: int64

# %%
data['FWI'].fillna(data['FWI'].mean())
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 239    6.5
# 240    0.0
# 241    0.2
# 242    0.7
# 243    0.5
# Name: FWI, Length: 244, dtype: float64

# %%
data.loc[160:170]
# Out:
#      day  month  Temperature   RH   Ws  Rain   FFMC   DMC     DC   ISI   BUI  \
# 160    9      7           36   43   15    1.9  82.3   9.4   9.90   3.2   9.0
# 161   10      7           34   51   16    3.8  77.5   8.0   9.50   2.0   7.7
# 162   11      7           34   56   15    2.9  74.8   7.1   9.50   1.6   6.8
# 163   12      7           36   44   13    0.0  90.1  12.6  19.40   8.3  12.5
# 164   13      7           39   45   13    0.6  85.2  11.3  10.40   4.2  10.9
# 165   14      7           37   37   18    0.2  88.9  12.9  14.69  12.5  10.4
# 166   15      7           34   45   17    0.0  90.5  18.0  24.10  10.9  17.7
# 167   16      7           31   83   17    0.0  84.5  19.4  33.10   4.7  19.2
# 168   17      7           32   81   17    0.0  84.6  21.1  42.30   4.7  20.9
# 169   18      7           33   68   15    0.0  86.1  23.9  51.60   5.2  23.9
# 170   19      7           34   58   16    0.0  88.1  27.8  61.10   7.3  27.7
#
#       FWI
# 160   3.1
# 161   1.3
# ...

# %%
data['FWI']=data['FWI'].fillna(data['FWI'].mean())

# %%
data.describe()
# Out:
#               day       month  Temperature          RH          Ws  \
# count  244.000000  244.000000   244.000000  244.000000  244.000000
# mean    15.754098    7.500000    32.172131   61.938525   15.504098
# std      8.825059    1.112961     3.633843   14.884200    2.810178
# min      1.000000    6.000000    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000    30.000000   52.000000   14.000000
# 50%     16.000000    7.500000    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000    35.000000   73.250000   17.000000
# max     31.000000    9.000000    42.000000   90.000000   29.000000
#
#             Rain         FFMC         DMC          DC         ISI         BUI  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean     0.760656   77.887705   14.673361   49.288484    4.774180   16.664754
# std      1.999406   14.337571   12.368039   47.619393    4.175318   14.204824
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(data['DC'])
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_4228\1134799417.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['DC'])

# %%
plt.figure(figsize=(15,8))
sns.boxenplot(data)
plt.show()

# %%
data['DC'].describe()
# Out:
# count    244.000000
# mean      49.288484
# std       47.619393
# min        6.900000
# 25%       13.275000
# 50%       33.100000
# 75%       68.150000
# max      220.400000
# Name: DC, dtype: float64

# %%
corelation=data.corr()

# %%
plt.figure(figsize=(18,8))
sns.heatmap(corelation,annot=True)
# Out:
# <AxesSubplot: >

# %%
data.head()
# Out:
#    day  month  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0    1      6           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9  0.5

# %%
x=data.drop(columns='Temperature')

# %%
y=data['Temperature']

# %%
x.head()
# Out:
#    day  month   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0    1      6   57   18    0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6   61   13    1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6   82   22   13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6   89   13    2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6   77   16    0.0  64.8  3.0  14.2  1.2  3.9  0.5

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([33.00345328, 35.02369093, 34.68710217, 33.14740046, 36.59955132,
#        31.83744269, 35.36787224, 28.30628959, 31.47113651, 29.20437787,
#        28.97902647, 32.74319299, 32.42314022, 32.54492354, 34.31238074,
#        31.85772427, 36.9439969 , 25.48314435, 32.62485883, 33.51915143,
#        31.07745274, 28.31043199, 34.40393581, 29.29108427, 36.76531437,
#        25.34436363, 33.56480183, 33.56185631, 33.54745143, 35.31627304,
#        33.94885058, 31.59443779, 32.57939011, 33.21448296, 32.38610134,
#        31.67169829, 30.02663844, 34.42994411, 32.10771544, 22.08846244,
#        33.99247888, 34.84569103, 31.30190098, 24.97982123, 36.17016696,
#        32.79838649, 31.16469422, 30.61212797, 35.40348684, 34.28009218,
#        37.14667157, 31.00707045, 30.86308821, 34.55292147, 33.55739709,
#        32.40887727, 36.7290891 , 30.54794239, 30.81085588, 36.23362554,
#        33.80870147, 28.60680794, 33.34061924, 31.69248015, 31.81913089,
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.5283351140425046

# %%
lr.score(x_train,y_train)
# Out:
# 0.5956741398831584

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5283351140425046

# %%
from sklearn.linear_model import ridge_regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_lr=Lasso()

# %%
lasso_lr.fit(x_train,y_train)
# Out:
# Lasso()

# %%
lasso_lr.score(x_train,y_train)
# Out:
# 0.5741143014023748

# %%
lasso_pred=lasso_lr.predict(x_test)

# %%
r2_score(y_test,lasso_pred)
# Out:
# 0.48598508604578394

# %%
from sklearn.linear_model import Ridge

# %%
ridge_lr=Ridge()

# %%
ridge_lr.fit(x_train,y_train)
# Out:
# Ridge()

# %%
ridge_pred=ridge_lr.predict(x_test)

# %%
ridge_lr.score(x_train,y_train)
# Out:
# 0.5956738128058476

# %%
r2_score(y_test,ridge_pred)
# Out:
# 0.5282792651889489

# %%
data.head()
# Out:
#    day  month  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0    1      6           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9  0.5
